# %% [markdown]
# # Principles of Data Analytics Problems

# %% [markdown]
# ## Problem 1: Creating the Repository
#
# For this problem, I created a GitHub repository for my assessment work. The repository contains the main files needed for the project, including a README file, a `.gitignore` file, a `requirements.txt` file, and this Jupyter notebook.
#
# The repository will be used to track my progress through the assessment problems and to show the development of my work over time using Git commits.

# %% [markdown]
# ## Problem 2: The README.md
#
# For this problem, I updated the `README.md` file.
#
# The README describes the purpose of the repository, lists the main files in the repository, and explains how to clone the repository, install the required packages, and open the Jupyter notebook.
#
# I also added a list of the assessment problems so that the structure of the project is clear.

# %% [markdown]
# ## Problem 3: gitignore
#
# For this problem, I added a `.gitignore` file to the repository.
#
# The purpose of the `.gitignore` file is to prevent unnecessary files from being tracked by Git. These can include temporary files, cache files, virtual environment folders, and Jupyter Notebook checkpoint files.
#
# Using a `.gitignore` file helps keep the repository organised and ensures that only important project files are committed.

# %% [markdown]
# ## Problem 4: The Notebook
#
# For this problem, I created a Jupyter notebook called `problems.ipynb`.
#
# The notebook will be used to complete the assessment problems using Python code cells and Markdown explanation cells.

# %%
# Import pandas for working with structured data.
import pandas as panda

# Import numpy for numerical calculations.
import numpy as numpy

# Import matplotlib.pyplot for creating plots and visualisations.
import matplotlib.pyplot as plot

# %% [markdown]
# The pandas library is used in data analytics for working with structured data. It provides the DataFrame object, which makes it easier to load, clean, explore, and summarise datasets.
#
# The numpy library is used for numerical computing. It provides arrays and mathematical functions that are useful when carrying out calculations on numerical data.
#
# The matplotlib.pyplot module is used for creating visualisations. In data analytics, plots such as histograms, scatter plots, and line plots help make patterns and relationships in data easier to understand.

# %% [markdown]
# ## Problem 5: The Penguins
#
# For the remaining problems, I will use the Palmer Penguins dataset.
#
# The Palmer Penguins dataset contains measurements for three penguin species: Adelie, Chinstrap, and Gentoo. The dataset includes variables such as bill length, bill depth, flipper length, body mass, island, sex, and year.
#
# In this problem, I load the dataset into a pandas DataFrame and use descriptive statistics to summarise the numeric variables.

# %%
# Load the Palmer Penguins dataset from a raw CSV URL.
penguins_url = "https://gist.githubusercontent.com/slopp/ce3b90b9168f2f921784de84fa445651/raw/penguins.csv"
penguins = panda.read_csv(penguins_url)

# %%
# Display the first five rows of the dataset.
penguins.head()
# Out:
#    rowid species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0      1  Adelie  Torgersen            39.1           18.7              181.0
# 1      2  Adelie  Torgersen            39.5           17.4              186.0
# 2      3  Adelie  Torgersen            40.3           18.0              195.0
# 3      4  Adelie  Torgersen             NaN            NaN                NaN
# 4      5  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007

# %%
# Display basic information about the dataset.
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              344 non-null    int64
#  1   species            344 non-null    object
#  2   island             344 non-null    object
#  3   bill_length_mm     342 non-null    float64
#  4   bill_depth_mm      342 non-null    float64
#  5   flipper_length_mm  342 non-null    float64
#  6   body_mass_g        342 non-null    float64
#  7   sex                333 non-null    object
#  8   year               344 non-null    int64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 24.3+ KB

# %%
# Calculate descriptive statistics for the numeric variables.
penguins[[
    "bill_length_mm",
    "bill_depth_mm",
    "flipper_length_mm",
    "body_mass_g"
]].describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %% [markdown]
# The `describe()` method gives descriptive statistics for the numeric variables in the dataset.
#
# The `mean` is the average value. It gives a general idea of the typical measurement for each variable.
#
# The `std` is the standard deviation. It shows how spread out the values are from the mean. A larger standard deviation means the values vary more.
#
# The quartiles show how the data is divided into sections. The `25%` value is the first quartile, meaning 25% of the values are below it. The `50%` value is the median, meaning half the values are below it and half are above it. The `75%` value is the third quartile, meaning 75% of the values are below it.
#
# Together, these statistics help describe the size, spread, and distribution of the penguin measurements.

# %% [markdown]
# ## Problem 6: Visualizing Distributions
#
# For this problem, I created visualisations to show the distribution of variables in the Palmer Penguins dataset.
#
# A distribution shows how the values of a variable are spread out. For numeric variables, histograms are useful because they show how often different ranges of values occur. For categorical variables, bar charts are useful because they show the number of observations in each category.
#
# To make the charts easier to read, I used descriptive labels for the variable names. For example, `bill_length_mm` is displayed as `Bill Length (mm)` and `body_mass_g` is displayed as `Body Mass (g)`.
#
# For the categorical variables, I also formatted the category names so that values such as `male` and `female` are displayed as `Male` and `Female` on the charts.

# %%
# Create histograms for the numeric variables in the Palmer Penguins dataset. 

numeric_columns = {
    "bill_length_mm": "Bill Length (mm)",
    "bill_depth_mm": "Bill Depth (mm)",
    "flipper_length_mm": "Flipper Length (mm)",
    "body_mass_g": "Body Mass (g)"
}

for column, label in numeric_columns.items():
    plot.figure(figsize=(6, 4))
    plot.hist(penguins[column].dropna(), bins=20)
    plot.title(f"Distribution of {label}")
    plot.xlabel(label)
    plot.ylabel("Frequency")
    plot.tight_layout()
    plot.show()

# %% [markdown]
# The histograms show the distributions of the numeric variables in the dataset.
#
# The `Bill Length (mm)` histogram shows the spread of penguin bill lengths. The values are not all centred around one single point, which may be because the dataset contains three different penguin species.
#
# The `Bill Depth (mm)` histogram shows the spread of bill depths. This variable also appears to have more than one cluster of values.
#
# The `Flipper Length (mm)` histogram shows variation in penguin flipper lengths. Some penguins have noticeably longer flippers than others.
#
# The `Body Mass (g)` histogram shows the distribution of penguin body masses. The values are spread over a wide range, showing that some penguins are much heavier than others.

# %%
# Create bar charts for categorical variables in the Palmer Penguins dataset.

categorical_columns = {
    "species": "Species",
    "island": "Island",
    "sex": "Sex"
}

for column, label in categorical_columns.items():
    plot.figure(figsize=(6, 4))

    # Capitalise the category names for display on the chart.
    counts = penguins[column].dropna().str.capitalize().value_counts()

    counts.plot(kind="bar")

    plot.title(f"Distribution of {label}")
    plot.xlabel(label)
    plot.ylabel("Count")
    plot.xticks(rotation=45)
    plot.tight_layout()
    plot.show()

# %% [markdown]
# The bar charts show the distributions of the categorical variables.
#
# The `Species` chart shows how many penguins belong to each species. This helps show whether the dataset is balanced across Adelie, Chinstrap, and Gentoo penguins.
#
# The `Island` chart shows how many penguins were recorded on each island.
#
# The `Sex` chart shows the number of male and female penguins in the dataset. The chart labels are capitalised to make them easier to read. Some values may be missing because not every penguin has a recorded sex value.

# %% [markdown]
# ## Problem 7: Investigating Relationships
#
# For this problem, I investigated whether larger penguins tend to have longer bills.
#
# I used a scatter plot to compare body mass and bill length. Body mass is shown on the X-axis and bill length is shown on the Y-axis.
#
# The points are colour-coded by species so that the three penguin species can be compared.

# %%
# Create a scatter plot to investigate whether larger penguins tend to have longer bills.

plot.figure(figsize=(8, 6))

plot.scatter(
    penguins["body_mass_g"],
    penguins["bill_length_mm"],
    alpha=0.7
)

plot.title("Relationship Between Body Mass and Bill Length")
plot.xlabel("Body Mass (g)")
plot.ylabel("Bill Length (mm)")
plot.grid(True)
plot.tight_layout()
plot.show()

# %% [markdown]
# The scatter plot shows the relationship between `Body Mass (g)` and `Bill Length (mm)`.
#
# There appears to be a positive relationship between the two variables. Penguins with a higher body mass often have longer bills.
#
# The points do not form a perfect straight line, so body mass does not perfectly predict bill length. However, the overall pattern suggests that the two measurements are related.

# %%
# Create a scatter plot of body mass and bill length, using different colours for each penguin species.

species_colours = {
    "Adelie": "tab:blue",
    "Chinstrap": "tab:orange",
    "Gentoo": "tab:green"
}

plot.figure(figsize=(8, 6))

for species, colour in species_colours.items():
    species_data = penguins[penguins["species"] == species]

    plot.scatter(
        species_data["body_mass_g"],
        species_data["bill_length_mm"],
        label=species,
        alpha=0.7,
        color=colour
    )

plot.title("Relationship Between Body Mass and Bill Length by Species")
plot.xlabel("Body Mass (g)")
plot.ylabel("Bill Length (mm)")
plot.legend(title="Species")
plot.grid(True)
plot.tight_layout()
plot.show()

# %% [markdown]
# The scatter plot with species shown separately gives more detail about the relationship between body mass and bill length.
#
# The chart shows that species is important. The different species appear in different parts of the chart, which means the relationship between body mass and bill length is not exactly the same for every species.
#
# Gentoo penguins generally have a higher body mass, while Adelie and Chinstrap penguins are generally lighter. Bill length also differs between the species.
#
# This means body mass is useful for understanding bill length, but species also matters.

# %% [markdown]
# ## Problem 8: Modelling the Data
#
# For this problem, I fitted a straight line to the relationship between body mass and bill length in the Palmer Penguins dataset.
#
# The aim is to investigate whether a penguin's body mass can be used to predict its bill length.
#
# A straight-line model has the form:
#
# `y = mx + c`
#
# where:
#
# - `y` is the predicted bill length.
# - `x` is the body mass.
# - `m` is the slope of the line.
# - `c` is the intercept.

# %%
# Select the columns needed for the model.
# Drop missing values so the model only uses complete rows.

model_data = penguins[["body_mass_g", "bill_length_mm"]].dropna()

x = model_data["body_mass_g"]
y = model_data["bill_length_mm"]

# %%
# Fit a straight line to the data using numpy.polyfit.
# The 1 means we want a straight line.

slope, intercept = numpy.polyfit(x, y, 1)

print(f"Slope: {slope:.4f}")
print(f"Intercept: {intercept:.4f}")
# Out:
# Slope: 0.0041
# Intercept: 26.8989

# %% [markdown]
# The slope and intercept are used to create the straight line.
#
# The slope shows how much the bill length changes as body mass increases.
#
# The intercept is where the line would start if body mass was zero. In this dataset, the intercept is mainly needed to draw the line.

# %%
# Use the slope and intercept to calculate the predicted bill length values.

predicted_y = slope * x + intercept

# %%
# Calculate the R-squared value.
# R-squared shows how well the line fits the data.

residuals = y - predicted_y
sum_squared_residuals = numpy.sum(residuals ** 2)

total_variation = y - numpy.mean(y)
total_sum_of_squares = numpy.sum(total_variation ** 2)

r_squared = 1 - (sum_squared_residuals / total_sum_of_squares)

print(f"R-squared: {r_squared:.4f}")
# Out:
# R-squared: 0.3542

# %% [markdown]
# The R-squared value shows how well the straight line fits the data.
#
# If R-squared is close to 1, the line is a very good fit.
#
# If R-squared is close to 0, the line is not a good fit.
#
# This helps show whether body mass is useful for estimating bill length.

# %%
# Plot the original data points and the straight-line model.

plot.figure(figsize=(8, 6))

plot.scatter(
    x,
    y,
    alpha=0.7,
    label="Penguins"
)

plot.plot(
    x,
    predicted_y,
    label="Best-Fit Line"
)

plot.title("Best-Fit Line for Body Mass and Bill Length")
plot.xlabel("Body Mass (g)")
plot.ylabel("Bill Length (mm)")
plot.legend()
plot.grid(True)
plot.tight_layout()
plot.show()

# %% [markdown]
# The chart shows the penguins as points and the straight-line model as a line.
#
# The line shows the general relationship between body mass and bill length.
#
# The chart suggests that heavier penguins often have longer bills. However, the points are not all close to the line, so the model is not perfect.
#
# This means body mass can give us some idea of bill length, but it cannot predict bill length exactly. Other information, such as the penguin species, would probably help make a better prediction.

# %% [markdown]
# ## End
